# %% [markdown]
# # Bike counts at Coupure Ghent

# %% [markdown]
# Created by S. Van Hoey

# %%
# %matplotlib inline

# %%
import pandas as pd
import seaborn as sns

# %%
bikecount = pd.read_csv("fietstellingencoupure201105tot201208.csv", sep=";",
                        parse_dates=[[0,1]], dayfirst=True)
bikecount = bikecount.set_index("dag_tijdstip")

# %%
bikecount.head()
# Out:
#                      noord  zuid actief
# dag_tijdstip
# 2011-05-25 11:34:07      8     2    NaN
# 2011-05-25 11:45:20      8     2    OFF
# 2011-05-25 18:22:20      8     2    OFF
# 2011-06-09 14:01:30      8     2    OFF
# 2011-06-10 09:55:34      8     2    OFF

# %%
bikecount["20110714":][["noord", "zuid"]].plot(figsize=(12, 6))
